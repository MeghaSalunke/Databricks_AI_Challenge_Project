# %%
# %sql
SHOW TABLES IN default;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>bronze_admission_data</td><td>false</td></tr><tr><td>default</td><td>bronze_emergency_room_data</td><td>false</td></tr><tr><td>default</td><td>bronze_er_wait_time</td><td>false</td></tr><tr><td>default</td><td>bronze_events</td><td>false</td></tr><tr><td>default</td><td>events_delta</td><td>false</td></tr><tr><td>default</td><td>events_table</td><td>false</td></tr><tr><td>default</td><td>gold_product_revenue</td><td>false</td></tr><tr><td>default</td><td>kaggle</td><td>false</td></tr><tr><td>default</td><td>silver_er_forecast</td><td>false</td></tr><tr><td>default</td><td>silver_er_wait_time</td><td>false</td></tr><tr><td>default</td><td>silver_events</td><td>false</td></tr><tr><td>default</td><td>silver_hospital_admissions</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE TABLE default.silver_er_wait_time;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>visit_id</td><td>string</td><td>null</td></tr><tr><td>patient_id</td><td>string</td><td>null</td></tr><tr><td>hospital_id</td><td>string</td><td>null</td></tr><tr><td>hospital_name</td><td>string</td><td>null</td></tr><tr><td>Region</td><td>string</td><td>null</td></tr><tr><td>visit_date</td><td>timestamp</td><td>null</td></tr><tr><td>day_of_week</td><td>string</td><td>null</td></tr><tr><td>season</td><td>string</td><td>null</td></tr><tr><td>time_of_day</td><td>string</td><td>null</td></tr><tr><td>urgency_level</td><td>string</td><td>null</td></tr><tr><td>nurse_patient_ratio</td><td>bigint</td><td>null</td></tr><tr><td>specialist_availability</td><td>bigint</td><td>null</td></tr><tr><td>facility_size_beds</td><td>bigint</td><td>null</td></tr><tr><td>time_to_registration_min</td><td>bigint</td><td>null</td></tr><tr><td>time_to_triage_min</td><td>bigint</td><td>null</td></tr><tr><td>time_to_medical_professional_min</td><td>bigint</td><td>null</td></tr><tr><td>total_wait_time_min</td><td>bigint</td><td>null</td></tr><tr><td>patient_outcome</td><td>string</td><td>null</td></tr><tr><td>patient_satisfaction</td><td>bigint</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM default.silver_er_wait_time;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>5000</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM default.silver_er_forecast;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>300</td></tr></tbody></table></div>

# %%
# %sql
SELECT
  COUNT(*) AS total_rows,
  SUM(CASE WHEN admission_date IS NULL THEN 1 ELSE 0 END) AS null_admission_dates
FROM default.silver_hospital_admissions;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_rows</th><th>null_admission_dates</th></tr></thead><tbody><tr><td>0</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TABLE default.gold_department_daily_load AS
SELECT
    CAST(w.visit_date AS DATE)           AS date,
    'Emergency'                           AS department,

    COUNT(DISTINCT w.patient_id)          AS total_admissions,

    -- operational metrics
    AVG(w.time_to_triage_min)             AS avg_triage_time_min,
    AVG(w.time_to_registration_min)       AS avg_registration_time_min,
    AVG(w.nurse_patient_ratio)            AS avg_nurse_patient_ratio,
    AVG(w.specialist_availability)        AS avg_specialist_availability,

    -- forecasted load
    COALESCE(SUM(f.patient_count),0)      AS forecasted_er_load,

    CURRENT_DATE()                        AS processing_date

FROM default.silver_er_wait_time w

LEFT JOIN default.silver_er_forecast f
    ON CAST(w.visit_date AS DATE) = CAST(f.date AS DATE)

GROUP BY CAST(w.visit_date AS DATE);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * 
FROM default.gold_department_daily_load
ORDER BY date
LIMIT 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>department</th><th>total_admissions</th><th>avg_triage_time_min</th><th>avg_registration_time_min</th><th>avg_nurse_patient_ratio</th><th>avg_specialist_availability</th><th>forecasted_er_load</th><th>processing_date</th></tr></thead><tbody><tr><td>2024-01-01</td><td>Emergency</td><td>10</td><td>36.4</td><td>21.3</td><td>3.2</td><td>5.0</td><td>960</td><td>2026-01-30</td></tr><tr><td>2024-01-02</td><td>Emergency</td><td>16</td><td>23.9375</td><td>9.1875</td><td>2.75</td><td>4.75</td><td>1392</td><td>2026-01-30</td></tr><tr><td>2024-01-03</td><td>Emergency</td><td>13</td><td>30.615384615384617</td><td>10.615384615384615</td><td>2.923076923076923</td><td>2.6153846153846154</td><td>1079</td><td>2026-01-30</td></tr><tr><td>2024-01-04</td><td>Emergency</td><td>10</td><td>39.3</td><td>17.4</td><td>3.4</td><td>2.6</td><td>910</td><td>2026-01-30</td></tr><tr><td>2024-01-05</td><td>Emergency</td><td>12</td><td>34.916666666666664</td><td>17.333333333333332</td><td>3.6666666666666665</td><td>3.75</td><td>948</td><td>2026-01-30</td></tr><tr><td>2024-01-06</td><td>Emergency</td><td>14</td><td>14.714285714285714</td><td>8.714285714285714</td><td>3.2857142857142856</td><td>2.357142857142857</td><td>1134</td><td>2026-01-30</td></tr><tr><td>2024-01-07</td><td>Emergency</td><td>13</td><td>33.07692307692308</td><td>16.076923076923077</td><td>3.8461538461538463</td><td>4.153846153846154</td><td>884</td><td>2026-01-30</td></tr><tr><td>2024-01-08</td><td>Emergency</td><td>16</td><td>25.125</td><td>13.0625</td><td>2.4375</td><td>5.0625</td><td>1296</td><td>2026-01-30</td></tr><tr><td>2024-01-09</td><td>Emergency</td><td>18</td><td>33.333333333333336</td><td>17.22222222222222</td><td>3.2222222222222223</td><td>6.555555555555555</td><td>1224</td><td>2026-01-30</td></tr><tr><td>2024-01-10</td><td>Emergency</td><td>10</td><td>26.3</td><td>14.7</td><td>3.2</td><td>5.0</td><td>740</td><td>2026-01-30</td></tr><tr><td>2024-01-11</td><td>Emergency</td><td>10</td><td>32.7</td><td>14.3</td><td>3.1</td><td>3.3</td><td>800</td><td>2026-01-30</td></tr><tr><td>2024-01-12</td><td>Emergency</td><td>13</td><td>24.153846153846153</td><td>12.538461538461538</td><td>2.6923076923076925</td><td>3.6153846153846154</td><td>1053</td><td>2